# %% [markdown]
# <a href="https://colab.research.google.com/github/devindianushika/data_analysis1/blob/master/dataStandardization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Standardization

# %%
import pandas as pd
df= pd.read_csv("cleaned_data.csv")

# %%
df.head()
# Out:
#    symboling  normalized-losses         make  ... city-mpg highway-mpg    price
# 0          3                122  alfa-romero  ...       21          27  13495.0
# 1          3                122  alfa-romero  ...       21          27  16500.0
# 2          1                122  alfa-romero  ...       19          26  16500.0
# 3          2                164         audi  ...       24          30  13950.0
# 4          2                164         audi  ...       18          22  17450.0
#
# [5 rows x 26 columns]

# %%
#unit transformation
# Convert mpg to L/100km by mathematical operation (235 divided by mpg)
df['highway-L/100km'] = (235/df["highway-mpg"])
df.head()
# Out:
#    symboling  normalized-losses  ...    price highway-L/100km
# 0          3                122  ...  13495.0        8.703704
# 1          3                122  ...  16500.0        8.703704
# 2          1                122  ...  16500.0        9.038462
# 3          2                164  ...  13950.0        7.833333
# 4          2                164  ...  17450.0       10.681818
#
# [5 rows x 27 columns]

# %%
df['city-L/100km']= (235/df["city-mpg"])

# %%
df.head()
# Out:
#    symboling  normalized-losses  ... highway-L/100km city-L/100km
# 0          3                122  ...        8.703704    11.190476
# 1          3                122  ...        8.703704    11.190476
# 2          1                122  ...        9.038462    12.368421
# 3          2                164  ...        7.833333     9.791667
# 4          2                164  ...       10.681818    13.055556
#
# [5 rows x 28 columns]

# %% [markdown]
# Data Normalization

# %%
#set data in width.length,height into 0-1 range
df['height']=df['height']/df['height'].max()
df['length']=df['length']/df['length'].max()
df['width']=df['width']/df['width'].max()

# %%
df.head()
# Out:
#    symboling  normalized-losses  ... highway-L/100km city-L/100km
# 0          3                122  ...        8.703704    11.190476
# 1          3                122  ...        8.703704    11.190476
# 2          1                122  ...        9.038462    12.368421
# 3          2                164  ...        7.833333     9.791667
# 4          2                164  ...       10.681818    13.055556
#
# [5 rows x 28 columns]

# %% [markdown]
# Binning

# %%
import numpy as np
bins = np.linspace(min(df['horsepower']),max(df['horsepower']),4)

# %%
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
df['horsepower_binned'] = pd.cut(df['horsepower'],bins,labels=group_names,include_lowest=True)

# %%
df[['horsepower','horsepower_binned']].head()
# Out:
#    horsepower horsepower_binned
# 0       111.0               Low
# 1       111.0               Low
# 2       154.0            Medium
# 3       102.0               Low
# 4       115.0               Low

# %%
df['horsepower_binned'].value_counts()
# Out:
# Low       153
# Medium     43
# High        5
# Name: horsepower_binned, dtype: int64

# %%
#visualize data
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names,df['horsepower_binned'].value_counts())
# Out:
# <BarContainer object of 3 artists>

# %%
#converting categorical variables into numerical avriables
dummy_variables1 = pd.get_dummies(df['fuel-type'])

# %%
dummy_variables1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
dummy_variables1.rename(columns={'diesel':'fuel_type_diesel','gas':'fuel_type_gas'},inplace=True)

# %%
dummy_variables1.head()
# Out:
#    fuel_type_diesel  fuel_type_gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1

# %%
#merge dummy data into df
df=pd.concat([df,dummy_variables1],axis=1)
#drop fuel type
df.drop('fuel-type',axis=1,inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses  ... fuel_type_diesel fuel_type_gas
# 0          3                122  ...                0             1
# 1          3                122  ...                0             1
# 2          1                122  ...                0             1
# 3          2                164  ...                0             1
# 4          2                164  ...                0             1
#
# [5 rows x 30 columns]

# %%
dummy_variables2 = pd.get_dummies(df['aspiration'])

# %%
dummy_variables2.head()
# Out:
#    std  turbo
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
dummy_variables2.rename(columns={'std':'aspi_std','turbo':'aspi_turbo'},inplace=True)

# %%
dummy_variables2.head()
# Out:
#    aspi_std  aspi_turbo
# 0         1           0
# 1         1           0
# 2         1           0
# 3         1           0
# 4         1           0

# %%
df = pd.concat([df,dummy_variables2],axis=1)

# %%
df.drop('aspiration',axis=1,inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses  ... aspi_std aspi_turbo
# 0          3                122  ...        1          0
# 1          3                122  ...        1          0
# 2          1                122  ...        1          0
# 3          2                164  ...        1          0
# 4          2                164  ...        1          0
#
# [5 rows x 31 columns]

# %%
df.to_csv("standardize_data.csv")
